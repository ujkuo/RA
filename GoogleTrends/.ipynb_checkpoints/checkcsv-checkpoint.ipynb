# %%
# !ls
# Out:
# MeToo_20210302.csv                   metoo2_googleTrends.csv
# MeToo_excel_cleaned.csv              metoo2_trendLargerThan1000.txt
# checkcsv.ipynb                       metoo2_withKeywords_googleTrends.csv
# googleTrends.ipynb                   trend_larger_than_1000.txt
# metoo1_googleTrends.csv

# %%
import pandas as pd
name = pd.read_csv('metoo2_googleTrends.csv')
word = pd.read_csv('metoo2_withKeywords_googleTrends.csv')

# %%
name
# Out:
#            date  Cristiano Ronaldo  Ryan Seacrest  Neil deGrasse Tyson  \
# 0    2017-10-01                 12              1                    3
# 1    2017-10-08                 12              1                    2
# 2    2017-10-15                 11              1                    2
# 3    2017-10-22                 17              1                    2
# 4    2017-10-29                 12              1                    3
# ..          ...                ...            ...                  ...
# 104  2019-09-29                  9              0                    1
# 105  2019-10-06                  9              1                    3
# 106  2019-10-13                 10              0                    2
# 107  2019-10-20                  8              0                    2
# 108  2019-10-27                  8              0                    1
#
#      Aziz Ansari  Sean Hannity  Russell Simmons  Kevin Spacey  Stan Lee  \
# ...

# %%
word
# Out:
#            date  Robert Moore + metoo  Robert Moore + sexual harassment  \
# 0    2017-10-01                     4                                24
# 1    2017-10-08                     5                                42
# 2    2017-10-15                    82                                65
# 3    2017-10-22                    38                                54
# 4    2017-10-29                    26                                62
# ..          ...                   ...                               ...
# 104  2019-09-29                    11                                32
# 105  2019-10-06                    13                                32
# 106  2019-10-13                    13                                29
# 107  2019-10-20                    13                                27
# 108  2019-10-27                    13                                25
#
#      Robert Moore + sexual  Robert Moore + healmetoo  Robert Moore + assault  \
# ...
